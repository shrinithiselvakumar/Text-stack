# %%
# First need to connect kernel to the internet, and install plotly_express
# !pip install plotly_express

# %%
import plotly_express as px
gapminder = px.data.gapminder()
gapminder2007 = gapminder.query("year == 2007")

px.scatter(gapminder2007, x="gdpPercap", y="lifeExp")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
df = pd.read_csv(r"/content/kasthuri dataset 1.csv")

# %%
df.head()
# Out:
#    Gender  Age           City Profession       Sleep Duration Dietary Habits  \
# 0    Male   33  Visakhapatnam    Student          '5-6 hours'        Healthy
# 1  Female   24      Bangalore    Student          '5-6 hours'       Moderate
# 2    Male   31       Srinagar    Student  'Less than 5 hours'        Healthy
# 3  Female   28       Varanasi    Student          '7-8 hours'       Moderate
# 4  Female   25         Jaipur    Student          '5-6 hours'       Moderate
#
#     Degree
# 0  B.Pharm
# 1      BSc
# 2       BA
# 3      BCA
# 4   M.Tech

# %%
import plotly_express as px
import pandas as pd



df = pd.read_csv(r"/content/kasthuri dataset 1.csv")

px.scatter(data_frame=df, x="City", y="Profession")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(data_frame=df, x="City", y="Profession",  size_max=60)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(data_frame=df, x="City", y="Profession", size_max=60, log_x=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
df
# Out:
#        Gender  Age           City Profession       Sleep Duration  \
# 0        Male   33  Visakhapatnam    Student          '5-6 hours'
# 1      Female   24      Bangalore    Student          '5-6 hours'
# 2        Male   31       Srinagar    Student  'Less than 5 hours'
# 3      Female   28       Varanasi    Student          '7-8 hours'
# 4      Female   25         Jaipur    Student          '5-6 hours'
# ...       ...  ...            ...        ...                  ...
# 27896  Female   27          Surat    Student          '5-6 hours'
# 27897    Male   27       Ludhiana    Student  'Less than 5 hours'
# 27898    Male   31      Faridabad    Student          '5-6 hours'
# 27899  Female   18       Ludhiana    Student  'Less than 5 hours'
# 27900    Male   27          Patna    Student  'Less than 5 hours'
#
#       Dietary Habits      Degree
# 0            Healthy     B.Pharm
# 1           Moderate         BSc
# 2            Healthy          BA
# 3           Moderate         BCA
# ...
