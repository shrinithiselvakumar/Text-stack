# %%
import pandas as pd
import numpy as np

# %%
#missing data
import numpy as np
import pandas as pd # Import pandas here to ensure it's available in this cell

d = {
    'A': [1,2, np.nan],
    'B':[5, np.nan, np.nan],
    'C':[1,2,3]
}
df = pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis = 0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna??

# %%
df.dropna(axis = 1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value = 'Filling Value')
# Out:
#                A              B  C
# 0            1.0            5.0  1
# 1            2.0  Filling Value  2
# 2  Filling Value  Filling Value  3

# %%
df = pd.DataFrame(d)

# %%
a = df['A'].fillna(value = df['A'].mean())

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
# Calculate the mean only for the 'Sales' column after grouping
byComp = df.groupby('Company')
byComp['Sales'].mean()
# Out:
# Company
# FB        183.5
# Google    160.0
# IBM       350.0
# MSFT      340.0
# Name: Sales, dtype: float64

# %%
byComp.sum()
# Out:
#            Person  Sales
# Company
# FB       VanRakib    367
# Google   SamNihad    320
# IBM           Ovi    350
# MSFT          Any    340

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
# Calculate the standard deviation only for the 'Sales' column after grouping
byComp['Sales'].std()
# Out:
# Company
# FB        84.145707
# Google    56.568542
# IBM             NaN
# MSFT            NaN
# Name: Sales, dtype: float64

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])
df1
# Out:
#     W   X   Y
# 1   5   7  19
# 2   5   1   3
# 3  11  19   9
# 4   4   4   8

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])
df1

df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])

# Corrected the typo 'randin' to 'randint'
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])
df1
# Out:
#     W   X   Y
# 1   4  13  11
# 2   3   3  17
# 3  13   4  12
# 4  14   7  11

# %%
df2
# Out:
#     W   X   Y
# 5  30  25  39
# 6  26  38  25
# 7  26  27  24
# 8  35  24  22

# %%
df3
# Out:
#      W   X   Y
# 9   48  57  43
# 10  49  46  58
# 11  47  50  51
# 12  44  56  55

# %%
farme = [df1, df2, df3]
pd.concat(farme)
# Out:
#      W   X   Y
# 1    4  13  11
# 2    3   3  17
# 3   13   4  12
# 4   14   7  11
# 5   30  25  39
# 6   26  38  25
# 7   26  27  24
# 8   35  24  22
# 9   48  57  43
# 10  49  46  58
# 11  47  50  51
# 12  44  56  55

# %%
pd.concat(farme, axis = 1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1    4.0  13.0  11.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2    3.0   3.0  17.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   13.0   4.0  12.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   14.0   7.0  11.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  30.0  25.0  39.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  26.0  38.0  25.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  26.0  27.0  24.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  35.0  24.0  22.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  48.0  57.0  43.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  49.0  46.0  58.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  47.0  50.0  51.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  44.0  56.0  55.0

# %%
eft = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
left
# Out:
# {'key': ['k0', 'k1', 'k2', 'k3'], 'A': [10, 20, 30, 40], 'B': [1, 2, 3, 4]}

# %%
right
# Out:
# {'key': ['k0', 'k1', 'k2', 'k3'],
#  'C': [100, 200, 300, 400],
#  'D': [11, 12, 13, 14]}

# %%
pd.merge??
